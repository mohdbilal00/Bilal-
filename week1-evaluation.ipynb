# %% [markdown]
# 1 : Write a program that:
#     - Takes name and age from user
#     - Prints:
#         Hello <name>, you are <age> years old

# %% [markdown]
# 2 : Take a number from user and print its square.

# %% [markdown]
# 3 : Take 5 numbers from user, store them in a list, and print the list.

# %% [markdown]
# 4 : Take a number from user and print whether it is Even or Odd.

# %% [markdown]
# 5 : Take a string from user and print the total number of characters (excluding spaces).

# %% [markdown]
# 6 : Take 5 numbers, store in a list, and print the sum of all numbers (do not use sum()).

# %% [markdown]
# 7 : Take 5 numbers from user, store in a list, and find the largest number without using max().

# %% [markdown]
# 8 : Ask user to enter yes or no.
#     - Accept input in any case (YES, Yes, yes)
#     - Print Confirmed only if input is yes

# %% [markdown]
# 9 : Take a sentence from user and print:
#         Total number of words

# %% [markdown]
# 10 : Write a program that:
#         - Takes 3 expense categories and amounts
#         - Stores them in a dictionary
#         - Prints the dictionary

# %% [markdown]
# 11 : Extend Q10:
#         - Calculate total expense
#         - Ask monthly income
#         - Print remaining balance
#         - Print warning if expenses exceed income

# %% [markdown]
# 12 : Write a program that:
#         - Takes a sentence
#         - Converts it to lowercase
#         - Splits into words
#         - Prints:
#             * Total words
#             * Total vowels count
